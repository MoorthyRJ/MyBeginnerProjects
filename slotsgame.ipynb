# %%
import random
import time
sympols=["😂","🥵","🍔","💩","💀"]

def spin():
  m=random.choices(sympols,k=3)
  return m
def main():

  print(" "*50)
  print("Welcome to slot machine")
  print(" "*50)
  print(sympols)
  currentbalc=100
  print(f"current balc is {currentbalc:.2f}")
  while currentbalc>0:
    m=spin()
    try:
      start=int(input("Place you bet amount:"))
      if start<=0:
        print("bet higher:")
      elif(start>currentbalc):
        print("insufficient balc")
      else:
        print("spining...")


        print(f"|{m[0]}|{m[1]}|{m[2]}|")




        if m[0]==m[1] and m[0]==m[2]:
          if m[0]=="😂":
            print("\n--"*20)
            print("you won 10x")
            print("\n--"*20)
            currentbalc+=start*10
          else:
            print("\n you won.")
            currentbalc+=start*5
        else:
          print("you lost")
          currentbalc-=start
        print(f"Your current balc:{currentbalc}")
        if currentbalc==0:
          break
        else:
          print(" "*50)
          again=input("Wanna bet again(y/n)").lower()
          print(" "*50)
          if again in ["yes","y"]:

            continue
          elif again =="cheat":
            print(f"|{m[0]}|{m[0]}|{m[0]}|")
            print("you won.")
            currentbalc+=start*5

            print(f"Your current balc:{currentbalc}")
            continue

          else:

            break
    except ValueError:
        print("invalid input")
    except KeyboardInterrupt:
       print("thanks for playing.")
  print(" "*50)
  print("  Thanks for playing.  ")
  print(" "*50)


if __name__=="__main__":
  main()
# Out:
#
# Welcome to slot machine
#
# ['😂', '🥵', '🍔', '💩', '💀']
# current balc is 100.00
# spining...
# |💀|💀|💀|
#
#  you won.
# Your current balc:125
#
#
# |💀|💀|💀|
# you won.
# Your current balc:150
# invalid input
# spining...
# |💩|🍔|😂|
# you lost
# Your current balc:144
#
#
# |💩|💩|💩|
# you won.
# Your current balc:174
# thanks for playing.
