# %%
import  string
import random
char=" "+string.punctuation+string.digits+string.ascii_letters


def encryption(word):

    newword=[]

    for i in word:

      ciphertext=random.choice(char)

      newword.append(ciphertext)
    result="".join(newword)
    return result




def main():
  database={}
  print(" "*50)
  print("    <welcome to Enctryption>")
  print(" "*50)
  while True:
    word=input("Enter the word:")
    if word=="":
      break



    if word in database:
      print(f'Its Encrpted Message:{word}')
      print(f"The Original message:{database[word]}")



    elif word in database.values():

       print(f'Original message:{word}')
       print(f"Encrypeted message:{encryptedword}")
    else:
      encryptedword=encryption(word)
      database[encryptedword]=word




      print(f"Original Text:{word}")
      print(f"Encrypted Text:{encryptedword}")


if __name__=="__main__":
    main()
# Out:
#
#     <welcome to Enctryption>
#
# Enter the word:qwertyu
# Original Text:qwertyu
# Encrypted Text:/Xtca:$
# Enter the word:qwertyu
# Original message:qwertyu
# Encrypeted message:/Xtca:$
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4088948477.py in <cell line: 0>()
#      53
#      54 if __name__=="__main__":
# ---> 55     main()
#      56
#      57
#
# /tmp/ipython-input-4088948477.py in main()
#      25   print(" "*50)
#      26   while True:
# ---> 27     word=input("Enter the word:")
#      28     if word=="":
#      29       break
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
# ...
